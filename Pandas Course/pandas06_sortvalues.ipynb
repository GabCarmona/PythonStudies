# %%
import pandas as pd
df = pd.read_excel(r'/home/gabriel/Downloads/Dados.xlsx')

# %%
#sorting using sort_values
df.sort_values(by='FirstName', ascending=True, inplace=True).head() #inplace = True, altera o dataframe original
#as colunas a serem ordenadas podem ser passadas na forma de uma lista de strings. Ex: by=['FirstName', 'LastName']
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1
